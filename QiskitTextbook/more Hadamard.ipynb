# %%
from ipynb.fs.full.quantum_helpers import draw_unitary, draw_statevector, draw_statevector_ket, draw_histogram, draw_qsphere, draw_tensor
from qiskit import QuantumCircuit

ckt = QuantumCircuit(1)
ckt.h(0)
ckt.z(0)
ckt.x(0)
ckt.draw()
# Out:
#    ┌───┐┌───┐┌───┐
# q: ┤ H ├┤ Z ├┤ X ├
#    └───┘└───┘└───┘

# %%
draw_unitary(ckt)
# Out:
# $$
# U=
# \begin{bmatrix}
# - \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
ckt = QuantumCircuit(2)
ckt.h(0)
ckt.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      └───┘
# q_1: ─────

# %%
draw_statevector(ckt)
# Out:
# $$\frac{\sqrt{2}}{2} |00\rangle+\frac{\sqrt{2}}{2} |01\rangle$$

# %%
draw_statevector_ket(ckt)
# Out:
# $$
# \text{Statevector} =
# \begin{bmatrix}
# \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \end{bmatrix}
# $$

# %%
ckt = QuantumCircuit(2)
ckt.x(1)
ckt.h(0)
ckt.cx(0, 1)
ckt.draw()
# Out:
#      ┌───┐
# q_0: ┤ H ├──■──
#      ├───┤┌─┴─┐
# q_1: ┤ X ├┤ X ├
#      └───┘└───┘

# %%
draw_statevector_ket(ckt)
# Out:
# $$
# \text{Statevector} =
# \begin{bmatrix}
# 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0  \\
#  \end{bmatrix}
# $$

# %%
draw_qsphere(ckt.copy())

# %%
draw_unitary(ckt)
# Out:
# $$
# U=
# \begin{bmatrix}
# 0 & 0 & \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2}  \\
#  \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2} & 0 & 0  \\
#  \frac{\sqrt{2}}{2} & \frac{\sqrt{2}}{2} & 0 & 0  \\
#  0 & 0 & \frac{\sqrt{2}}{2} & - \frac{\sqrt{2}}{2}  \\
#  \end{bmatrix}
# $$

# %%
draw_tensor(ckt)
# Out:
# (0.7071067811865475+0j)

# %%
ckt.measure_all()
draw_histogram(ckt)
