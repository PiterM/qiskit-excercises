# %%
import qiskit.tools.jupyter
# %qiskit_version_table
# Out:
# <h3>Version Information</h3><table><tr><th>Qiskit Software</th><th>Version</th></tr><tr><td><code>qiskit-terra</code></td><td>0.21.2</td></tr><tr><td><code>qiskit-aer</code></td><td>0.10.4</td></tr><tr><td><code>qiskit-ibmq-provider</code></td><td>0.19.2</td></tr><tr><td><code>qiskit</code></td><td>0.37.2</td></tr><tr><th>System information</th></tr><tr><td>Python version</td><td>3.9.13</td></tr><tr><td>Python compiler</td><td>GCC 11.2.0</td></tr><tr><td>Python build</td><td>main, Aug 25 2022 23:26:10</td></tr><tr><td>OS</td><td>Linux</td></tr><tr><td>CPUs</td><td>4</td></tr><tr><td>Memory (Gb)</td><td>11.589241027832031</td></tr><tr><td colspan='2'>Thu Feb 16 22:45:04 2023 CET</td></tr></table>

# %%
from qiskit import IBMQ, QuantumCircuit, transpile, Aer
from qiskit.tools import job_monitor
from qiskit.visualization import plot_histogram, plot_gate_map

# %%
# Loading your IBM Quantum account(s)
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2023-02-16 22:45:05,323: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
backend = Aer.get_backend("qasm_simulator")

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.measure_all()
qc.draw(output='mpl')

# %%
import qiskit.tools.jupyter
# %qiskit_job_watcher
# Out:
# Accordion(children=(VBox(layout=Layout(max_width='710px', min_width='710px')),), layout=Layout(max_height='500…

# %%
# run job on real hardware
job = backend.run(transpile(qc, backend=backend), shots=1024)

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
plot_histogram(job.result().get_counts())
